# %% [markdown]
# # AI Community @ Семинар № 8
# ## Поиск фигур на изображении

# %%
import cv2
import imutils
import numpy as np
import seaborn as sns
from collections import OrderedDict
from skimage.io import imshow
from scipy.spatial import distance as dist
from matplotlib import pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['axes.grid'] = False

# %%
class ShapeDetector:
    """
    Class which detects shapes given contour.
    """
    
    def detect(self, c):
        shape = "unidentified"
        peri = cv2.arcLength(c, True)
        # approximates a contour shape to another shape with less number 
        # of vertices depending upon the precision we specify
        polygon = cv2.approxPolyDP(c, 0.04 * peri, True)
        if len(polygon) == 3:
            shape = "triangle"
        elif len(polygon) == 4:
            (x, y, w, h) = cv2.boundingRect(polygon)
            ar = w / float(h)
            shape = "square" if ar >= 0.95 and ar <= 1.05 else "rectangle"
        else:
            shape = "circle"
        return shape

# %% [markdown]
# OpenCV загружает изображения в формате BGR.
# Превратим BGR в RGB и уменьшим изображение:

# %%
image = cv2.imread("./images/shapes.jpg")[:, :, ::-1]
# image_rbg = cv2.cvtColor(image, cv2.COLOR_BAYER_BG2RGB)
resized = imutils.resize(image, width=300)
resized_original = resized.copy()
resized_colors = resized.copy()
ratio = image.shape[0] / float(resized.shape[0])

# %%
imshow(resized);

# %% [markdown]
# Для поиска контуров нужно бинаризованное изображение.
# Сначала переведем изображение в оттенки серого:

# %%
gray = cv2.cvtColor(resized, cv2.COLOR_RGB2GRAY)
imshow(gray);

# %% [markdown]
# Затем бинаризуем:

# %%
thresh = cv2.threshold(gray, 60, 255, cv2.THRESH_BINARY)[1]
imshow(thresh)

# %%
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
thresh = cv2.threshold(blurred, 60, 255, cv2.THRESH_BINARY)[1]

# %%
imshow(thresh)

# %% [markdown]
# Найдем контуры:

# %%
contours, hier = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours = contours[1] #if imutils.is_cv2() else contours[1]

# %% [markdown]
# Определим тип каждого объекта по его контуру.
# Для этого используем наш класс `ShapeDetector`:
#
# Моменты изображения помогают вам вычислить некоторые функции, такие как центр масс объекта, площадь объекта и т. д.

# %%
contours
# Out:
# [array([[[ 34, 279]]], dtype=int32),
#  array([[[ 32, 276]]], dtype=int32),
#  array([[[ 34, 274]]], dtype=int32),
#  array([[[  1, 274]]], dtype=int32),
#  array([[[ 70, 272]]], dtype=int32),
#  array([[[ 37, 271]]], dtype=int32),
#  array([[[ 23, 271]]], dtype=int32),
#  array([[[112, 198]],
#
#         [[112, 199]],
#
#         [[111, 200]],
#
#         [[111, 201]],
#
#         [[110, 202]],
#
#         [[110, 203]],
#
#         [[109, 204]],
#
#         [[109, 206]],
#
#         [[108, 207]],
#
#         [[108, 208]],
#
#         [[107, 209]],
#
#         [[107, 210]],
#
#         [[106, 211]],
#
#         [[106, 213]],
#
#         [[105, 214]],
#
#         [[105, 215]],
#
#         [[106, 216]],
#
#         [[107, 216]],
#
#         [[110, 219]],
#
#         [[111, 219]],
#
#         [[113, 221]],
#
#         [[114, 221]],
#
#         [[117, 224]],
#
#         [[119, 224]],
#
#         [[120, 223]],
#
#         [[121, 223]],
#
#         [[122, 222]],
#
#         [[123, 222]],
#
#         [[125, 220]],
#
#         [[126, 220]],
#
#         [[127, 219]],
#
#         [[128, 219]],
#
#         [[129, 218]],
#
#         [[130, 218]],
#
#         [[132, 216]],
#
#         [[133, 216]],
#
#         [[134, 215]],
#
#         [[133, 214]],
#
#         [[133, 212]],
#
#         [[132, 211]],
#
#         [[132, 209]],
#
#         [[131, 208]],
#
#         [[131, 205]],
#
#         [[130, 204]],
#
#         [[130, 202]],
#
#         [[129, 201]],
#
#         [[129, 199]],
#
#         [[128, 198]]], dtype=int32),
#  array([[[170, 186]],
#
#         [[169, 187]],
#
#         [[168, 187]],
#
#         [[167, 188]],
#
#         [[166, 188]],
#
#         [[164, 190]],
#
#         [[163, 190]],
#
#         [[162, 191]],
#
#         [[161, 191]],
#
#         [[160, 192]],
#
#         [[159, 192]],
#
#         [[157, 194]],
#
#         [[156, 194]],
#
#         [[155, 195]],
#
#         [[154, 195]],
#
#         [[153, 196]],
#
#         [[152, 196]],
#
#         [[150, 198]],
#
#         [[149, 198]],
#
#         [[148, 199]],
#
#         [[147, 199]],
#
#         [[146, 200]],
#
#         [[145, 200]],
#
#         [[143, 202]],
#
#         [[142, 202]],
#
#         [[141, 203]],
#
#         [[140, 203]],
#
#         [[139, 204]],
#
#         [[139, 205]],
#
#         [[140, 206]],
#
#         [[140, 207]],
#
#         [[142, 209]],
#
#         [[142, 210]],
#
#         [[144, 212]],
#
#         [[144, 213]],
#
#         [[146, 215]],
#
#         [[146, 216]],
#
#         [[147, 217]],
#
#         [[147, 218]],
#
#         [[149, 220]],
#
#         [[149, 221]],
#
#         [[150, 222]],
#
#         [[150, 223]],
#
#         [[152, 225]],
#
#         [[152, 226]],
#
#         [[153, 227]],
#
#         [[153, 228]],
#
#         [[155, 230]],
#
#         [[155, 231]],
#
#         [[156, 232]],
#
#         [[156, 233]],
#
#         [[157, 234]],
#
#         [[157, 235]],
#
#         [[158, 236]],
#
#         [[158, 237]],
#
#         [[160, 239]],
#
#         [[160, 240]],
#
#         [[161, 241]],
#
#         [[161, 242]],
#
#         [[162, 243]],
#
#         [[162, 244]],
#
#         [[164, 246]],
#
#         [[164, 247]],
#
#         [[165, 248]],
#
#         [[165, 249]],
#
#         [[166, 250]],
#
#         [[166, 251]],
#
#         [[167, 252]],
#
#         [[167, 253]],
#
#         [[169, 255]],
#
#         [[169, 256]],
#
#         [[170, 257]],
#
#         [[170, 258]],
#
#         [[171, 259]],
#
#         [[171, 260]],
#
#         [[172, 261]],
#
#         [[172, 262]],
#
#         [[173, 263]],
#
#         [[175, 263]],
#
#         [[177, 261]],
#
#         [[178, 261]],
#
#         [[179, 260]],
#
#         [[180, 260]],
#
#         [[181, 259]],
#
#         [[182, 259]],
#
#         [[183, 258]],
#
#         [[184, 258]],
#
#         [[185, 257]],
#
#         [[186, 257]],
#
#         [[187, 256]],
#
#         [[188, 256]],
#
#         [[189, 255]],
#
#         [[190, 255]],
#
#         [[191, 254]],
#
#         [[192, 254]],
#
#         [[193, 253]],
#
#         [[194, 253]],
#
#         [[195, 252]],
#
#         [[196, 252]],
#
#         [[197, 251]],
#
#         [[198, 251]],
#
#         [[199, 250]],
#
#         [[200, 250]],
#
#         [[201, 249]],
#
#         [[202, 249]],
#
#         [[203, 248]],
#
#         [[204, 248]],
#
#         [[205, 247]],
#
#         [[205, 245]],
#
#         [[203, 243]],
#
#         [[203, 242]],
#
#         [[202, 241]],
#
#         [[202, 240]],
#
#         [[200, 238]],
#
#         [[200, 237]],
#
#         [[199, 236]],
#
#         [[199, 235]],
#
#         [[198, 234]],
#
#         [[198, 233]],
#
#         [[196, 231]],
#
#         [[196, 230]],
#
#         [[195, 229]],
#
#         [[195, 228]],
#
#         [[194, 227]],
#
#         [[194, 226]],
#
#         [[192, 224]],
#
#         [[192, 223]],
#
#         [[191, 222]],
#
#         [[191, 221]],
#
#         [[190, 220]],
#
#         [[190, 219]],
#
#         [[188, 217]],
#
#         [[188, 216]],
#
#         [[187, 215]],
#
#         [[187, 214]],
#
#         [[186, 213]],
#
#         [[186, 212]],
#
#         [[184, 210]],
#
#         [[184, 209]],
#
#         [[183, 208]],
#
#         [[183, 207]],
#
#         [[182, 206]],
#
#         [[182, 205]],
#
#         [[180, 203]],
#
#         [[180, 202]],
#
#         [[179, 201]],
#
#         [[179, 200]],
#
#         [[178, 199]],
#
#         [[178, 198]],
#
#         [[176, 196]],
#
#         [[176, 195]],
#
#         [[175, 194]],
#
#         [[175, 193]],
#
#         [[174, 192]],
#
#         [[174, 191]],
#
#         [[172, 189]],
#
#         [[172, 188]],
#
#         [[171, 187]],
#
#         [[171, 186]]], dtype=int32),
#  array([[[235, 183]],
#
#         [[234, 184]],
#
#         [[230, 184]],
#
#         [[229, 185]],
#
#         [[225, 185]],
#
#         [[224, 186]],
#
#         [[220, 186]],
#
#         [[219, 187]],
#
#         [[215, 187]],
#
#         [[214, 188]],
#
#         [[209, 188]],
#
#         [[208, 189]],
#
#         [[204, 189]],
#
#         [[203, 190]],
#
#         [[202, 190]],
#
#         [[202, 192]],
#
#         [[203, 193]],
#
#         [[203, 197]],
#
#         [[204, 198]],
#
#         [[204, 202]],
#
#         [[205, 203]],
#
#         [[205, 207]],
#
#         [[206, 208]],
#
#         [[206, 213]],
#
#         [[207, 214]],
#
#         [[207, 218]],
#
#         [[208, 219]],
#
#         [[208, 223]],
#
#         [[209, 223]],
#
#         [[209, 222]],
#
#         [[212, 219]],
#
#         [[212, 218]],
#
#         [[215, 215]],
#
#         [[215, 214]],
#
#         [[218, 211]],
#
#         [[218, 210]],
#
#         [[220, 208]],
#
#         [[220, 207]],
#
#         [[223, 204]],
#
#         [[223, 203]],
#
#         [[227, 199]],
#
#         [[227, 198]],
#
#         [[230, 195]],
#
#         [[230, 194]],
#
#         [[233, 191]],
#
#         [[233, 190]],
#
#         [[237, 186]],
#
#         [[237, 185]],
#
#         [[239, 183]]], dtype=int32),
#  array([[[ 12, 174]]], dtype=int32),
#  array([[[ 71, 158]],
#
#         [[ 70, 159]],
#
#         [[ 69, 159]],
#
#         [[ 69, 178]],
#
#         [[ 70, 179]],
#
#         [[ 70, 207]],
#
#         [[ 71, 208]],
#
#         [[ 71, 218]],
#
#         [[ 79, 218]],
#
#         [[ 80, 217]],
#
#         [[ 87, 217]],
#
#         [[ 87, 214]],
#
#         [[ 86, 213]],
#
#         [[ 86, 195]],
#
#         [[ 85, 194]],
#
#         [[ 85, 175]],
#
#         [[ 84, 174]],
#
#         [[ 84, 158]]], dtype=int32),
#  array([[[192, 150]],
#
#         [[191, 151]],
#
#         [[190, 151]],
#
#         [[189, 152]],
#
#         [[188, 152]],
#
#         [[184, 156]],
#
#         [[184, 157]],
#
#         [[183, 158]],
#
#         [[183, 159]],
#
#         [[182, 160]],
#
#         [[182, 170]],
#
#         [[183, 171]],
#
#         [[183, 172]],
#
#         [[184, 173]],
#
#         [[184, 174]],
#
#         [[188, 178]],
#
#         [[189, 178]],
#
#         [[190, 179]],
#
#         [[191, 179]],
#
#         [[192, 180]],
#
#         [[202, 180]],
#
#         [[203, 179]],
#
#         [[204, 179]],
#
#         [[205, 178]],
#
#         [[206, 178]],
#
#         [[211, 173]],
#
#         [[211, 172]],
#
#         [[212, 171]],
#
#         [[212, 170]],
#
#         [[213, 169]],
#
#         [[213, 166]],
#
#         [[214, 165]],
#
#         [[214, 164]],
#
#         [[213, 163]],
#
#         [[213, 159]],
#
#         [[212, 158]],
#
#         [[212, 157]],
#
#         [[211, 156]],
#
#         [[211, 155]],
#
#         [[208, 152]],
#
#         [[207, 152]],
#
#         [[206, 151]],
#
#         [[205, 151]],
#
#         [[204, 150]]], dtype=int32),
#  array([[[ 90, 150]],
#
#         [[ 90, 151]],
#
#         [[ 93, 154]],
#
#         [[ 93, 155]],
#
#         [[ 95, 157]],
#
#         [[ 95, 158]],
#
#         [[ 98, 161]],
#
#         [[ 98, 162]],
#
#         [[101, 165]],
#
#         [[101, 166]],
#
#         [[103, 168]],
#
#         [[103, 169]],
#
#         [[106, 172]],
#
#         [[106, 173]],
#
#         [[109, 176]],
#
#         [[109, 177]],
#
#         [[112, 180]],
#
#         [[112, 181]],
#
#         [[116, 185]],
#
#         [[116, 186]],
#
#         [[119, 189]],
#
#         [[119, 177]],
#
#         [[120, 176]],
#
#         [[120, 161]],
#
#         [[121, 160]],
#
#         [[121, 152]],
#
#         [[117, 152]],
#
#         [[116, 151]],
#
#         [[100, 151]],
#
#         [[ 99, 150]]], dtype=int32),
#  array([[[131, 130]],
#
#         [[131, 152]],
#
#         [[132, 153]],
#
#         [[132, 183]],
#
#         [[159, 183]],
#
#         [[160, 182]],
#
#         [[160, 130]]], dtype=int32),
#  array([[[232, 116]],
#
#         [[232, 134]],
#
#         [[231, 135]],
#
#         [[231, 145]],
#
#         [[241, 145]],
#
#         [[242, 146]],
#
#         [[259, 146]],
#
#         [[259, 120]],
#
#         [[260, 119]],
#
#         [[260, 117]],
#
#         [[247, 117]],
#
#         [[246, 116]]], dtype=int32),
#  array([[[168, 111]],
#
#         [[167, 112]],
#
#         [[165, 112]],
#
#         [[161, 116]],
#
#         [[161, 117]],
#
#         [[160, 118]],
#
#         [[160, 123]],
#
#         [[161, 124]],
#
#         [[161, 126]],
#
#         [[162, 127]],
#
#         [[162, 128]],
#
#         [[164, 130]],
#
#         [[165, 130]],
#
#         [[166, 131]],
#
#         [[167, 131]],
#
#         [[168, 132]],
#
#         [[173, 132]],
#
#         [[174, 131]],
#
#         [[175, 131]],
#
#         [[176, 130]],
#
#         [[177, 130]],
#
#         [[177, 129]],
#
#         [[179, 127]],
#
#         [[179, 126]],
#
#         [[180, 125]],
#
#         [[180, 120]],
#
#         [[179, 119]],
#
#         [[179, 117]],
#
#         [[178, 116]],
#
#         [[178, 115]],
#
#         [[176, 113]],
#
#         [[175, 113]],
#
#         [[174, 112]],
#
#         [[173, 112]],
#
#         [[172, 111]]], dtype=int32),
#  array([[[199,  91]],
#
#         [[198,  92]],
#
#         [[193,  92]],
#
#         [[193, 138]],
#
#         [[215, 138]],
#
#         [[216, 139]],
#
#         [[216, 128]],
#
#         [[217, 127]],
#
#         [[217,  91]]], dtype=int32),
#  array([[[ 68,  90]],
#
#         [[ 67,  91]],
#
#         [[ 65,  91]],
#
#         [[ 64,  92]],
#
#         [[ 63,  92]],
#
#         [[ 62,  93]],
#
#         [[ 61,  93]],
#
#         [[ 60,  94]],
#
#         [[ 59,  94]],
#
#         [[ 57,  96]],
#
#         [[ 56,  96]],
#
#         [[ 53,  99]],
#
#         [[ 53, 100]],
#
#         [[ 51, 102]],
#
#         [[ 51, 103]],
#
#         [[ 50, 104]],
#
#         [[ 50, 106]],
#
#         [[ 49, 107]],
#
#         [[ 49, 110]],
#
#         [[ 48, 111]],
#
#         [[ 48, 118]],
#
#         [[ 49, 119]],
#
#         [[ 49, 121]],
#
#         [[ 50, 122]],
#
#         [[ 50, 124]],
#
#         [[ 52, 126]],
#
#         [[ 52, 127]],
#
#         [[ 53, 128]],
#
#         [[ 53, 129]],
#
#         [[ 57, 133]],
#
#         [[ 58, 133]],
#
#         [[ 59, 134]],
#
#         [[ 60, 134]],
#
#         [[ 61, 135]],
#
#         [[ 62, 135]],
#
#         [[ 63, 136]],
#
#         [[ 65, 136]],
#
#         [[ 66, 137]],
#
#         [[ 70, 137]],
#
#         [[ 71, 138]],
#
#         [[ 75, 138]],
#
#         [[ 76, 137]],
#
#         [[ 80, 137]],
#
#         [[ 81, 136]],
#
#         [[ 83, 136]],
#
#         [[ 84, 135]],
#
#         [[ 85, 135]],
#
#         [[ 87, 133]],
#
#         [[ 88, 133]],
#
#         [[ 91, 130]],
#
#         [[ 91, 129]],
#
#         [[ 93, 127]],
#
#         [[ 93, 126]],
#
#         [[ 94, 125]],
#
#         [[ 94, 123]],
#
#         [[ 95, 122]],
#
#         [[ 95, 119]],
#
#         [[ 96, 118]],
#
#         [[ 96, 113]],
#
#         [[ 95, 112]],
#
#         [[ 95, 108]],
#
#         [[ 94, 107]],
#
#         [[ 94, 106]],
#
#         [[ 93, 105]],
#
#         [[ 93, 104]],
#
#         [[ 92, 103]],
#
#         [[ 92, 101]],
#
#         [[ 85,  94]],
#
#         [[ 84,  94]],
#
#         [[ 82,  92]],
#
#         [[ 81,  92]],
#
#         [[ 80,  91]],
#
#         [[ 78,  91]],
#
#         [[ 77,  90]]], dtype=int32),
#  array([[[158,  84]],
#
#         [[158,  98]],
#
#         [[172,  98]],
#
#         [[173,  99]],
#
#         [[179,  99]],
#
#         [[179,  97]],
#
#         [[180,  96]],
#
#         [[180,  84]]], dtype=int32),
#  array([[[ 93,  78]],
#
#         [[ 93,  81]],
#
#         [[ 92,  82]],
#
#         [[ 92,  92]],
#
#         [[104,  92]],
#
#         [[105,  93]],
#
#         [[106,  93]],
#
#         [[107,  92]],
#
#         [[107,  78]]], dtype=int32),
#  array([[[136,  67]],
#
#         [[135,  68]],
#
#         [[134,  68]],
#
#         [[133,  69]],
#
#         [[132,  69]],
#
#         [[131,  70]],
#
#         [[130,  70]],
#
#         [[129,  71]],
#
#         [[128,  71]],
#
#         [[127,  72]],
#
#         [[126,  72]],
#
#         [[125,  73]],
#
#         [[124,  73]],
#
#         [[122,  75]],
#
#         [[121,  75]],
#
#         [[120,  76]],
#
#         [[119,  76]],
#
#         [[118,  77]],
#
#         [[117,  77]],
#
#         [[116,  78]],
#
#         [[115,  78]],
#
#         [[116,  79]],
#
#         [[116,  82]],
#
#         [[117,  83]],
#
#         [[117,  86]],
#
#         [[118,  87]],
#
#         [[118,  90]],
#
#         [[119,  91]],
#
#         [[119,  94]],
#
#         [[120,  95]],
#
#         [[120,  97]],
#
#         [[121,  98]],
#
#         [[121, 101]],
#
#         [[122, 102]],
#
#         [[126, 102]],
#
#         [[127, 103]],
#
#         [[133, 103]],
#
#         [[134, 104]],
#
#         [[139, 104]],
#
#         [[140, 105]],
#
#         [[141, 105]],
#
#         [[142, 104]],
#
#         [[142, 103]],
#
#         [[143, 102]],
#
#         [[143, 101]],
#
#         [[144, 100]],
#
#         [[144,  98]],
#
#         [[145,  97]],
#
#         [[145,  96]],
#
#         [[146,  95]],
#
#         [[146,  94]],
#
#         [[147,  93]],
#
#         [[147,  92]],
#
#         [[148,  91]],
#
#         [[148,  90]],
#
#         [[149,  89]],
#
#         [[149,  88]],
#
#         [[150,  87]],
#
#         [[150,  86]],
#
#         [[151,  85]],
#
#         [[151,  84]],
#
#         [[152,  83]]], dtype=int32),
#  array([[[109,  38]],
#
#         [[108,  39]],
#
#         [[108,  40]],
#
#         [[109,  41]],
#
#         [[109,  59]],
#
#         [[113,  59]],
#
#         [[114,  60]],
#
#         [[116,  60]],
#
#         [[117,  59]],
#
#         [[130,  59]],
#
#         [[130,  58]],
#
#         [[129,  57]],
#
#         [[130,  56]],
#
#         [[130,  55]],
#
#         [[129,  54]],
#
#         [[129,  38]]], dtype=int32),
#  array([[[49, 36]],
#
#         [[48, 37]],
#
#         [[48, 70]],
#
#         [[47, 71]],
#
#         [[47, 72]],
#
#         [[54, 72]],
#
#         [[55, 73]],
#
#         [[84, 73]],
#
#         [[84, 71]],
#
#         [[85, 70]],
#
#         [[85, 39]],
#
#         [[84, 39]],
#
#         [[83, 38]],
#
#         [[68, 38]],
#
#         [[67, 37]],
#
#         [[51, 37]],
#
#         [[50, 36]]], dtype=int32),
#  array([[[187,  28]],
#
#         [[186,  29]],
#
#         [[185,  29]],
#
#         [[184,  30]],
#
#         [[183,  30]],
#
#         [[182,  31]],
#
#         [[181,  31]],
#
#         [[180,  32]],
#
#         [[179,  32]],
#
#         [[178,  33]],
#
#         [[176,  33]],
#
#         [[175,  34]],
#
#         [[174,  34]],
#
#         [[173,  35]],
#
#         [[172,  35]],
#
#         [[171,  36]],
#
#         [[170,  36]],
#
#         [[169,  37]],
#
#         [[168,  37]],
#
#         [[167,  38]],
#
#         [[166,  38]],
#
#         [[165,  39]],
#
#         [[164,  39]],
#
#         [[163,  40]],
#
#         [[162,  40]],
#
#         [[162,  48]],
#
#         [[163,  49]],
#
#         [[163,  57]],
#
#         [[164,  58]],
#
#         [[164,  67]],
#
#         [[165,  68]],
#
#         [[168,  68]],
#
#         [[169,  69]],
#
#         [[176,  69]],
#
#         [[177,  70]],
#
#         [[183,  70]],
#
#         [[184,  71]],
#
#         [[190,  71]],
#
#         [[191,  72]],
#
#         [[192,  72]],
#
#         [[192,  71]],
#
#         [[194,  69]],
#
#         [[194,  68]],
#
#         [[195,  67]],
#
#         [[195,  66]],
#
#         [[197,  64]],
#
#         [[197,  63]],
#
#         [[199,  61]],
#
#         [[199,  60]],
#
#         [[200,  59]],
#
#         [[200,  58]],
#
#         [[202,  56]],
#
#         [[202,  55]],
#
#         [[203,  54]],
#
#         [[203,  53]],
#
#         [[204,  52]],
#
#         [[204,  51]],
#
#         [[206,  49]],
#
#         [[206,  47]],
#
#         [[204,  45]],
#
#         [[204,  44]],
#
#         [[194,  34]],
#
#         [[193,  34]],
#
#         [[191,  32]],
#
#         [[191,  31]],
#
#         [[188,  28]]], dtype=int32),
#  array([[[287,  10]]], dtype=int32)]

# %%
resized_copy = resized.copy()
sd = ShapeDetector()
for i, contour in enumerate(contours):
    M = cv2.moments(contour)
    cX = int((M["m10"] / M["m00"]))
    cY = int((M["m01"] / M["m00"]))
    shape = sd.detect(contour)

    contour = contour.astype("int")
    cv2.drawContours(resized, [contour], -1, (0, 255, 0), 2)
    cv2.putText(resized, shape, (cX, cY), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-143-f9c8b2372e7e> in <module>
#       3 for i, contour in enumerate(contours):
#       4     M = cv2.moments(contour)
# ----> 5     cX = int((M["m10"] / M["m00"]))
#       6     cY = int((M["m01"] / M["m00"]))
#       7     shape = sd.detect(contour)
#
# ZeroDivisionError: float division by zero

# %%
imshow(resized);

# %% [markdown]
# Попробуем определить цвет фигур

# %%
def get_color(image, contour):
    mask = np.zeros(image.shape[:2], dtype="uint8")
    cv2.drawContours(mask, [contour], -1, 255, -1)
    mask = cv2.erode(mask, None, iterations=2)
    mean = cv2.mean(image, mask=mask)[:3]
    
    colors = OrderedDict({
        "red": (255, 0, 0),
        "green": (0, 255, 0),
        "blue": (0, 0, 255),
        "yellow": (255,255,0)
        
    })
    lab = np.zeros((len(colors), 1, 3), dtype="uint8")
    for (i, (name, rgb)) in enumerate(colors.items()):
        lab[i] = rgb
    lab = cv2.cvtColor(lab, cv2.COLOR_RGB2LAB)
    current_color = (None, np.inf)
    color_indices = {0: 'red', 1: 'green', 2: 'blue', 3:'yellow'}
    for index, color in enumerate(lab):
        new_dist = dist.euclidean(color, mean)
        if new_dist < current_color[1]:
            current_color = (color_indices[index], new_dist)
    return current_color[0]

# %%
for contour in contours:
    M = cv2.moments(contour)
    cX = int((M["m10"] / M["m00"]))
    cY = int((M["m01"] / M["m00"]))
    shape = sd.detect(contour)

    contour = contour.astype("int")
    cv2.drawContours(resized_copy, [contour], -1, (0, 255, 0), 2)
    color = get_color(cv2.cvtColor(resized_original, cv2.COLOR_RGB2LAB), contour)
    text = "{} {}".format(color, shape)
    cv2.putText(resized_colors, text, (cX, cY), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-131-8275ea692721> in <module>
#       1 for contour in contours:
#       2     M = cv2.moments(contour)
# ----> 3     cX = int((M["m10"] / M["m00"]))
#       4     cY = int((M["m01"] / M["m00"]))
#       5     shape = sd.detect(contour)
#
# ZeroDivisionError: float division by zero

# %%
imshow(resized_colors);
